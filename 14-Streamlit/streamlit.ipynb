# %% [markdown]
# # Introduction
# Streamlit is an open source app framework for machine learning and data science projects. It allow you to create beautiful web applications for your machine learning and data science projects with simple python scripts
