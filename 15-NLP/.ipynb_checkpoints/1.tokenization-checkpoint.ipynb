# %%
# !pip install nltk

# %%
corpus = """Hello welcome, to my home.
Please do something on yourself! to become better."""

# %%
print(corpus)
# Out:
# Hello welcome, to my home.
# Please do something on yourself! to become better.

# %%
## Tokenization
## Sentence --> paragraphs
import nltk
nltk.download('punkt_tab')   # Newer Punkt data (recommended in recent NLTK)
nltk.download('punkt')       # For backward compatibility
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\thesi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\thesi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello welcome, to my home.
# Please do something on yourself!
# to become better.

# %%
## Tokenizations
## paragraph --> words
## sentence --> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'my',
#  'home',
#  '.',
#  'Please',
#  'do',
#  'something',
#  'on',
#  'yourself',
#  '!',
#  'to',
#  'become',
#  'better',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %% [raw]
# worpunct_tokenize(corpus)

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'my',
#  'home.',
#  'Please',
#  'do',
#  'something',
#  'on',
#  'yourself',
#  '!',
#  'to',
#  'become',
#  'better',
#  '.']
